# %%
import pandas as pd

# %%
provinces = ['BKK','Chiangmai','Khonkaen','Rayong','Saraburi','Surat']
province = provinces[0]

data_test = pd.read_csv(province+'_clean.csv', date_parser = True)
data_test = data_test.drop(['Unnamed: 0', 'lat', 'long'], axis = 1)
data_test.head()
# Out:
#              date_time  PM2.5  temp  wind speed  wind dir
# 0  2020-07-01 00:00:00   19.0  25.9          23       260
# 1  2020-07-01 01:00:00   22.0  25.2          21       255
# 2  2020-07-01 02:00:00   28.0  25.2          21       255
# 3  2020-07-01 03:00:00   25.0  25.2          21       255
# 4  2020-07-01 04:00:00   19.0  24.7          29       255

# %%
def chk_time(x):
    
    if(x[11:13] in ['00','06','12','18']):
        return True
    return False

# %%
data_test['chk_time'] = data_test['date_time'].apply(lambda x: chk_time(x))
data_test.head(10)
# Out:
#              date_time  PM2.5  temp  wind speed  wind dir  chk_time
# 0  2020-07-01 00:00:00   19.0  25.9          23       260      True
# 1  2020-07-01 01:00:00   22.0  25.2          21       255     False
# 2  2020-07-01 02:00:00   28.0  25.2          21       255     False
# 3  2020-07-01 03:00:00   25.0  25.2          21       255     False
# 4  2020-07-01 04:00:00   19.0  24.7          29       255     False
# 5  2020-07-01 05:00:00   19.0  24.7          29       255     False
# 6  2020-07-01 06:00:00   23.0  24.7          29       255      True
# 7  2020-07-01 07:00:00   22.0  25.4          35       250     False
# 8  2020-07-01 08:00:00   21.0  25.4          35       250     False
# 9  2020-07-01 09:00:00   23.0  25.4          35       250     False

# %%
data_test = data_test[data_test['chk_time']]
data_test.head(10)
# Out:
#               date_time  PM2.5  temp  wind speed  wind dir  chk_time
# 0   2020-07-01 00:00:00   19.0  25.9          23       260      True
# 6   2020-07-01 06:00:00   23.0  24.7          29       255      True
# 12  2020-07-01 12:00:00   18.0  29.3          36       250      True
# 18  2020-07-01 18:00:00   16.0  31.8          29       260      True
# 24  2020-07-02 00:00:00   18.0  25.9          25       270      True
# 30  2020-07-02 06:00:00   27.0  24.6          25       265      True
# 36  2020-07-02 12:00:00   16.0  29.6          23       250      True
# 42  2020-07-02 18:00:00   11.0  29.1          27       260      True
# 48  2020-07-03 00:00:00    5.0  25.7          29       260      True
# 54  2020-07-03 06:00:00   14.0  25.0          41       245      True

# %%
data_test.drop(['chk_time'],axis=1,inplace=True)

# %%
data_test
# Out:
#                 date_time  PM2.5  temp  wind speed  wind dir
# 0     2020-07-01 00:00:00   19.0  25.9          23       260
# 6     2020-07-01 06:00:00   23.0  24.7          29       255
# 12    2020-07-01 12:00:00   18.0  29.3          36       250
# 18    2020-07-01 18:00:00   16.0  31.8          29       260
# 24    2020-07-02 00:00:00   18.0  25.9          25       270
# ...                   ...    ...   ...         ...       ...
# 8754  2021-06-30 18:00:00   12.0  28.7          14       270
# 8760  2021-07-01 00:00:00   11.0  25.3          11       255
# 8766  2021-07-01 06:00:00   11.0  23.8          11       255
# 8772  2021-07-01 12:00:00   13.0  32.2           9       235
# 8778  2021-07-01 18:00:00   13.0  27.9          12       250
#
# [1464 rows x 5 columns]

# %%
data_test.to_csv(province+'_clean2.csv',index=False)
